# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import matplotlib.pyplot as plt
import sklearn.metrics as metrics

# %%
data = pd.read_csv('data.csv')
del data['Unnamed: 32']

# %%
X = data.iloc[:, 2:].values
y = data.iloc[:, 1].values

# Encoding categorical data
from sklearn.preprocessing import LabelEncoder
labelencoder_X_1 = LabelEncoder()
y = labelencoder_X_1.fit_transform(y)


from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 0)


from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
model = Sequential()
model.add(Dense(16, activation="relu", input_dim=(30)))
       
model.add(Dense(16, activation="relu"))

model.add(Dense(1, activation="sigmoid"))

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, batch_size=100, epochs=150)
# Out:
# Epoch 1/150
# 6/6 [==============================] - 2s 3ms/step - loss: 0.5689 - accuracy: 0.7344
# Epoch 2/150
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4900 - accuracy: 0.8379
# Epoch 3/150
# 6/6 [==============================] - 0s 3ms/step - loss: 0.4287 - accuracy: 0.8672
# Epoch 4/150
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3813 - accuracy: 0.8848
# Epoch 5/150
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3409 - accuracy: 0.8906
# Epoch 6/150
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3088 - accuracy: 0.9004
# Epoch 7/150
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2820 - accuracy: 0.9082
# Epoch 8/150
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2587 - accuracy: 0.9199
# Epoch 9/150
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2391 - accuracy: 0.9316
# Epoch 10/150
# ...

# %%
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5)
# Out:
# 2/2 [==============================] - 0s 3ms/step

# %%
print(y_pred)
# Out:
# [[ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
# Out:
# Accuracy: 0.9649122807017544
# Precision: 0.9166666666666666
# Recall: 1.0
# F1-score: 0.9565217391304348

# %%
predicted_labels =y_pred  
true_labels = y_test

# %%
import matplotlib.pyplot as plt
import sklearn.metrics as metrics


classes = ["benign", "malignant"]  



cm = metrics.confusion_matrix(true_labels, predicted_labels)
plt.figure(figsize=(5, 5))
plt.imshow(cm, cmap="Blues", interpolation="nearest")
plt.colorbar()
plt.title("Confusion Matrix")
plt.xticks(range(len(classes)), classes, rotation=45)
plt.yticks(range(len(classes)), classes)
plt.tight_layout()
plt.show()

# %%
import seaborn as sns

sns.heatmap(cm, annot=True, fmt="d")
plt.title("Heatmap of Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
# in this task when i checked the data  i found out that there was unamed colomn so after many tryies the best one was to exclude it (delet)
#i converted target y to numerical then i implent neural network to predict whether it is B or M an i got accuracy of 96%
#then i visualized it
